# %%
import polyan
import pandas as pd
import matplotlib.pyplot as plt

# %%
part1 = pd.read_csv('Data/GSM2476121_cnt_1.txt',sep='\t', header=None)
part2 = pd.read_csv('Data/GSM2476122_cnt_2.txt',sep='\t', header=None)
HEK =

# %%
combined = part1[['Gene','na']].merge(part2[['Gene','na']],on='Gene',how='outer')

# %%
fig,ax = plt.subplots()
ax.scatter(part1.na,part2.na,s=0.5)
plt.show()

# %%
combined['Ribo_Prints'] = combined['na_x'] + combined['na_y']

# %%
test = polyan.fp2poly(combined,parset='HEK')
# Out:
# Using parameterset for HEK293 cell line
# No mRNA data specified, using reference RNA-Seq data.

# %%
coords = polyan.plot_poly(test)
fig,ax = plt.subplots()
ax.plot(coords[0],coords[1])
plt.show()

# %%
test
# Out:
# array([0.01784739, 0.03464494, 0.1469613 , 0.05232058, 0.08139125,
#        0.08618456, 0.0804495 , 0.0648528 , 0.05782788, 0.04494439,
#        0.03851256, 0.03302135, 0.03050798, 0.02542755, 0.0198104 ,
#        0.0185305 , 0.01612976, 0.01476277, 0.01310127, 0.01341333,
#        0.01230643, 0.01257451, 0.01011255, 0.00973389, 0.01094502,
#        0.00984733, 0.00860762, 0.00795832, 0.00784213, 0.008612  ,
#        0.00734989, 0.00346828])
